# %%
import pandas as pd
import numpy as np
import datetime 
from matplotlib import pyplot as plt

data = pd.read_excel('voetbal_opdr.xlsx')
data.head()
# Out:
#       naam   naam.1         positie  aantal gemaakte goalen  geboortedatum  \
# 0  speler1  speler1          staart                       1            NaN
# 1  speler2  speler2          staart                       0            NaN
# 2  speler3  speler3   linkervleugel                       1            NaN
# 3  speler4  speler4  rechtervleugel                       0            NaN
# 4  speler5  speler5          piloot                       6            NaN
#
#   inzet  gewicht  lengte
# 0           25.3     123
# 1   NaN     29.2     134
# 2   NaN     22.8     116
# 3   NaN     23.2     121
# 4   NaN     24.5     121

# %%
start = pd.to_datetime('2011-01-01')
end = pd.to_datetime('2011-12-31')
start_u = start.value//10**9
end_u = end.value//10**9
cat1_date = pd.to_datetime('2011-04-01')
cat2_date = pd.to_datetime('2011-10-01')

# %%
for x, row in data.iterrows():
    y= (pd.to_datetime(np.random.randint(start_u, end_u), unit='s'))
    data.at[x, 'geboortedatum'] = datetime.date(y.year, y.month, y.day)
    inzet_text='matig'
    if y < cat1_date:
        inzet_text = 'zeer goed'
    elif y < cat2_date:
            inzet_text = 'goed'
    data.at[x,'inzet'] = str(inzet_text)
data.head()
# Out:
#       naam   naam.1         positie  aantal gemaakte goalen geboortedatum  \
# 0  speler1  speler1          staart                       1    2011-05-28
# 1  speler2  speler2          staart                       0    2011-01-07
# 2  speler3  speler3   linkervleugel                       1    2011-09-17
# 3  speler4  speler4  rechtervleugel                       0    2011-08-29
# 4  speler5  speler5          piloot                       6    2011-06-05
#
#        inzet  gewicht  lengte
# 0       goed     25.3     123
# 1  zeer goed     29.2     134
# 2       goed     22.8     116
# 3       goed     23.2     121
# 4       goed     24.5     121

# %%
gewicht_gesorteerd = sorted(set(data.gewicht))
for x in gewicht_gesorteerd:
    y=data[data.gewicht == x]
    plt.scatter(y.gewicht, y.lengte)
plt.xlim(19,31)
plt.ylim(110,140)
plt.xlabel('gewicht')
plt.ylabel('lengte')
plt.show()

# %%
sum_array = {}
for position in data['positie']:
    sum_array[position]=0
for x, row in data.iterrows():
    position=data.at[x, 'positie']
    sum_array[position]=sum_array[position]+ data.at[x, 'aantal gemaakte goalen']
x = list(sum_array.keys())
y = list(sum_array.values())
plt.bar(x,y)
plt.xlabel("Posities")
plt.ylabel("Aantal goals gescoord")
plt.title("Goals per positie")
plt.xticks(list(sum_array.keys()),list(sum_array.keys()), rotation='vertical')
plt.show()

# %%
data.head()
# Out:
#       naam   naam.1         positie  aantal gemaakte goalen geboortedatum  \
# 0  speler1  speler1          staart                       1    2011-05-28
# 1  speler2  speler2          staart                       0    2011-01-07
# 2  speler3  speler3   linkervleugel                       1    2011-09-17
# 3  speler4  speler4  rechtervleugel                       0    2011-08-29
# 4  speler5  speler5          piloot                       6    2011-06-05
#
#        inzet  gewicht  lengte
# 0       goed     25.3     123
# 1  zeer goed     29.2     134
# 2       goed     22.8     116
# 3       goed     23.2     121
# 4       goed     24.5     121
